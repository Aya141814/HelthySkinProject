# %% [markdown]
# <a href="https://colab.research.google.com/github/Aya141814/Suhada-Note/blob/main/Articles1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
test="abc"
print(test)
# Out:
# abc
